# %% [markdown]
# # District distances
#
# **Procedure**
# 1. create a DF of the congress with
#     1. all twitter id pairs
#     2. all district pairs
# 2. use geopandas to calculate distance between districts

# %%
import pandas as pd
from congress import Congress
import numpy as np

# %%
congress = Congress('qa1qfTzGinGGLcNCbinp2OTlI2SvzBe4KFgxYobm')

# %% [markdown]
# ### Load the congress data into DF

# %%
#load the congress data
df_house = pd.DataFrame(congress.members.filter('house', congress=115)[0]['members'])

# %%
#drop rows if twitter_account == None
house_twonly = df_house.dropna(subset=['twitter_account'])
#drop those who are not in office anymore
house_twonly = house_twonly[house_twonly.in_office].reset_index(drop=True)

# %% [markdown]
# ### Create pairs for each congresswomen

# %% [markdown]
# - for each member a (1 row), take another member b and add her information (with concat)

# %%
lastcol = house_twonly.shape[0]
member_pairs = pd.DataFrame()
df_list = []

for i in range(lastcol):
    mem = pd.DataFrame([house_twonly.iloc[i,:]]*(lastcol)).reset_index(drop=True) #create df with member i 
    mem = pd.concat([mem, house_twonly], axis=1) #merge member and others
    mem = mem.drop(mem.index[i]).reset_index(drop=True) #remove relf-reference
    df_list.append(mem) #store in list containing dataframes
    
#merge them all together
member_pairs = pd.concat(df_list)

# %%
member_pairs = member_pairs.reset_index(drop=True)

# %%
member_pairs.twitter_account.tail(3)
# Out:
#        twitter_account twitter_account
# 178503    RepLeeZeldin      RepTedYoho
# 178504    RepLeeZeldin   RepDavidYoung
# 178505    RepLeeZeldin     RepDonYoung

# %%
member_pairs.to_csv('member_pairs.csv')

# %% [markdown]
# ### Load voting districts into geopandas

# %%
import json
import os
import requests

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# spatial stuff
import geopandas as gpd
import fiona
import folium
import shapely

# %% [markdown]
# - shapefiles from https://www.census.gov/geo/maps-data/data/cbf/cbf_cds.html

# %%
#os.chdir("..\")
os.getcwd()
# Out:
# 'C:\\Users\\Philipp\\GDrive\\Coding\\Python\\SocialDataScience\\Project_tsds\\Philipp'

# %%
ppath = 'C:/Users/Philipp/GDrive/Coding/Python/SocialDataScience/Project_tsds/rawdata/congress_disticts2017_500k/'
districts = gpd.read_file(ppath+'cb_2017_us_cd115_500k.shp')

# %%
districts.head(3)
#GEOID or STATEFP gives congressional districts
# Out:
#   STATEFP CD115FP       AFFGEOID GEOID LSAD CDSESSN        ALAND     AWATER  \
# 0      13      09  5001500US1309  1309   C2     115  13497964615  411754565
# 1      19      04  5001500US1904  1904   C2     115  58937921470  264842664
# 2      17      10  5001500US1710  1710   C2     115    777307694   31695461
#
#                                             geometry
# 0  POLYGON ((-84.65622499999999 34.730984, -84.65...
# 1  POLYGON ((-96.63970399999999 42.737071, -96.63...
# 2  POLYGON ((-88.19882 42.41557, -88.198601 42.41...

# %% [markdown]
# ### Match districts via geoid

# %%
#generate centroids
def get_centroids(x):
    return x.centroid

districts['centroids'] = districts.geometry.apply(get_centroids)

# %%
districts.centroids[0].distance(districts.centroids[1])
# Out:
# 13.634726788599925

# %%
districts.geometry[0].distance(districts.geometry[1])
# Out:
# 10.771112182700213

# %% [markdown]
# >Do we better use centroids or polygons to calculate distances?

# %% [markdown]
# 1. load data
# 1. take geoid of member A and member B
#     1. there are two columns of geoid, the first is the reference member and the second all other matched members
# 2. insert centroids
# 2. calculate distances of centroids

# %%
member_pairs
# Out:
#                                                   api_uri  at_large  \
# 0       https://api.propublica.org/congress/v1/members...     False
# 1       https://api.propublica.org/congress/v1/members...     False
# 2       https://api.propublica.org/congress/v1/members...     False
# 3       https://api.propublica.org/congress/v1/members...     False
# 4       https://api.propublica.org/congress/v1/members...     False
# 5       https://api.propublica.org/congress/v1/members...     False
# 6       https://api.propublica.org/congress/v1/members...     False
# 7       https://api.propublica.org/congress/v1/members...     False
# 8       https://api.propublica.org/congress/v1/members...     False
# 9       https://api.propublica.org/congress/v1/members...     False
# 10      https://api.propublica.org/congress/v1/members...     False
# 11      https://api.propublica.org/congress/v1/members...     False
# 12      https://api.propublica.org/congress/v1/members...     False
# 13      https://api.propublica.org/congress/v1/members...     False
# 14      https://api.propublica.org/congress/v1/members...     False
# 15      https://api.propublica.org/congress/v1/members...     False
# 16      https://api.propublica.org/congress/v1/members...     False
# 17      https://api.propublica.org/congress/v1/members...     False
# 18      https://api.propublica.org/congress/v1/members...     False
# 19      https://api.propublica.org/congress/v1/members...     False
# 20      https://api.propublica.org/congress/v1/members...     False
# 21      https://api.propublica.org/congress/v1/members...     False
# 22      https://api.propublica.org/congress/v1/members...     False
# 23      https://api.propublica.org/congress/v1/members...     False
# 24      https://api.propublica.org/congress/v1/members...     False
# 25      https://api.propublica.org/congress/v1/members...     False
# 26      https://api.propublica.org/congress/v1/members...     False
# 27      https://api.propublica.org/congress/v1/members...     False
# 28      https://api.propublica.org/congress/v1/members...     False
# 29      https://api.propublica.org/congress/v1/members...     False
# ...                                                   ...       ...
# 178476  https://api.propublica.org/congress/v1/members...     False
# 178477  https://api.propublica.org/congress/v1/members...     False
# 178478  https://api.propublica.org/congress/v1/members...     False
# 178479  https://api.propublica.org/congress/v1/members...     False
# 178480  https://api.propublica.org/congress/v1/members...     False
# 178481  https://api.propublica.org/congress/v1/members...     False
# 178482  https://api.propublica.org/congress/v1/members...     False
# 178483  https://api.propublica.org/congress/v1/members...     False
# 178484  https://api.propublica.org/congress/v1/members...     False
# 178485  https://api.propublica.org/congress/v1/members...     False
# 178486  https://api.propublica.org/congress/v1/members...     False
# 178487  https://api.propublica.org/congress/v1/members...     False
# 178488  https://api.propublica.org/congress/v1/members...     False
# 178489  https://api.propublica.org/congress/v1/members...     False
# 178490  https://api.propublica.org/congress/v1/members...     False
# 178491  https://api.propublica.org/congress/v1/members...     False
# 178492  https://api.propublica.org/congress/v1/members...     False
# 178493  https://api.propublica.org/congress/v1/members...     False
# 178494  https://api.propublica.org/congress/v1/members...     False
# 178495  https://api.propublica.org/congress/v1/members...     False
# 178496  https://api.propublica.org/congress/v1/members...     False
# 178497  https://api.propublica.org/congress/v1/members...     False
# 178498  https://api.propublica.org/congress/v1/members...     False
# 178499  https://api.propublica.org/congress/v1/members...     False
# 178500  https://api.propublica.org/congress/v1/members...     False
# 178496         None  N00029404    61616    1980-01-30        1        0.355
# 178497         None  N00029404    61616    1980-01-30        1        0.355
# 178498         None  N00029404    61616    1980-01-30        1        0.355
# 178499         None  N00029404    61616    1980-01-30        1        0.355
# 178500         None  N00029404    61616    1980-01-30        1        0.355
# 178501         None  N00029404    61616    1980-01-30        1        0.355
# 178502         None  N00029404    61616    1980-01-30        1        0.355
# 178503         None  N00029404    61616    1980-01-30        1        0.355
# 178504         None  N00029404    61616    1980-01-30        1        0.355
# 178505         None  N00029404    61616    1980-01-30        1        0.355
#
#                facebook_account           fax  \
# 0       CongressmanRalphAbraham  202-225-5639
# 1       CongressmanRalphAbraham  202-225-5639
# 2       CongressmanRalphAbraham  202-225-5639
# 3       CongressmanRalphAbraham  202-225-5639
# 4       CongressmanRalphAbraham  202-225-5639
# 5       CongressmanRalphAbraham  202-225-5639
# 6       CongressmanRalphAbraham  202-225-5639
# 7       CongressmanRalphAbraham  202-225-5639
# 8       CongressmanRalphAbraham  202-225-5639
# 9       CongressmanRalphAbraham  202-225-5639
# 10      CongressmanRalphAbraham  202-225-5639
# 11      CongressmanRalphAbraham  202-225-5639
# 12      CongressmanRalphAbraham  202-225-5639
# 13      CongressmanRalphAbraham  202-225-5639
# 14      CongressmanRalphAbraham  202-225-5639
# 15      CongressmanRalphAbraham  202-225-5639
# 16      CongressmanRalphAbraham  202-225-5639
# 17      CongressmanRalphAbraham  202-225-5639
# 18      CongressmanRalphAbraham  202-225-5639
# 19      CongressmanRalphAbraham  202-225-5639
# 20      CongressmanRalphAbraham  202-225-5639
# 21      CongressmanRalphAbraham  202-225-5639
# 22      CongressmanRalphAbraham  202-225-5639
# 23      CongressmanRalphAbraham  202-225-5639
# 24      CongressmanRalphAbraham  202-225-5639
# 25      CongressmanRalphAbraham  202-225-5639
# 26      CongressmanRalphAbraham  202-225-5639
# 27      CongressmanRalphAbraham  202-225-5639
# 28      CongressmanRalphAbraham  202-225-5639
# 29      CongressmanRalphAbraham  202-225-5639
# ...                         ...           ...
# 178476             RepLeeZeldin  202-225-3143
# 178477             RepLeeZeldin  202-225-3143
# 178478             RepLeeZeldin  202-225-3143
# 178479             RepLeeZeldin  202-225-3143
# 178480             RepLeeZeldin  202-225-3143
# 178481             RepLeeZeldin  202-225-3143
# 178482             RepLeeZeldin  202-225-3143
# 178483             RepLeeZeldin  202-225-3143
# 178484             RepLeeZeldin  202-225-3143
# 178485             RepLeeZeldin  202-225-3143
# 178486             RepLeeZeldin  202-225-3143
# 178487             RepLeeZeldin  202-225-3143
# 178488             RepLeeZeldin  202-225-3143
# 178489             RepLeeZeldin  202-225-3143
# 178490             RepLeeZeldin  202-225-3143
# 178491             RepLeeZeldin  202-225-3143
# 178492             RepLeeZeldin  202-225-3143
# 178493             RepLeeZeldin  202-225-3143
# 178494             RepLeeZeldin  202-225-3143
# 178495             RepLeeZeldin  202-225-3143
# 178496             RepLeeZeldin  202-225-3143
# 178497             RepLeeZeldin  202-225-3143
# 178498             RepLeeZeldin  202-225-3143
# 178499             RepLeeZeldin  202-225-3143
# 178500             RepLeeZeldin  202-225-3143
# 178501             RepLeeZeldin  202-225-3143
# 178502             RepLeeZeldin  202-225-3143
# 178503             RepLeeZeldin  202-225-3143
# 178504             RepLeeZeldin  202-225-3143
# 178505             RepLeeZeldin  202-225-3143
#
#                             ...                                title  \
# 0                           ...                       Representative
# 1                           ...                       Representative
# 2                           ...                       Representative
# 3                           ...                       Representative
# 4                           ...                       Representative
# 5                           ...                       Representative
# 6                           ...                       Representative
# 7                           ...                       Representative
# 8                           ...                       Representative
# 9                           ...                       Representative
# 10                          ...                       Representative
# 11                          ...                       Representative
# 12                          ...                       Representative
# 13                          ...                       Representative
# 14                          ...                       Representative
# 15                          ...                       Representative
# 16                          ...                       Representative
# 17                          ...                       Representative
# 18                          ...                       Representative
# 19                          ...                       Representative
# 20                          ...                       Representative
# 21                          ...                       Representative
# 22                          ...                       Representative
# 23                          ...                       Representative
# 24                          ...                       Representative
# 25                          ...                       Representative
# 26                          ...                       Representative
# 27                          ...                       Representative
# 28                          ...                       Representative
# 29                          ...                       Representative
# ...                         ...                                  ...
# 178476                      ...                       Representative
# 178477                      ...                       Representative
# 178478                      ...                       Representative
# 178479                      ...                       Representative
# 178480                      ...                       Representative
# 178481                      ...                       Representative
# 178482                      ...                       Representative
# 178483                      ...                       Representative
# 178484                      ...                       Representative
# 178485                      ...                       Representative
# 178486                      ...                       Representative
# 178487                      ...                       Representative
# 178488                      ...                       Representative
# 178489                      ...                       Representative
# 178490                      ...                       Representative
# 178491                      ...                       Representative
# 178492                      ...                       Representative
# 178493                      ...                       Representative
# 178494                      ...                       Representative
# 178495                      ...                       Representative
# 178496                      ...                       Representative
# 178497                      ...                       Representative
# 178498                      ...                       Representative
# 178499                      ...                       Representative
# 178500                      ...                       Representative
# 178501                      ...                       Representative
# 178502                      ...                       Representative
# 178503                      ...                       Representative
# 178504                      ...                       Representative
# 178505                      ...                       Representative
#
#        total_present total_votes  twitter_account  \
# 0                0.0       940.0         RepAdams
# 1                0.0       940.0  Robert_Aderholt
# 2                0.0       940.0   reppeteaguilar
# 3                0.0       940.0     reprickallen
# 4                2.0       940.0    MarkAmodeiNV2
# 5                0.0       940.0     RepArrington
# 6                0.0       940.0    RepBrianBabin
# 7                0.0       940.0      RepDonBacon
# 8                0.0       940.0      RepJimBanks
# 9                0.0       940.0   RepLouBarletta
# 10               0.0       940.0      RepAndyBarr
# 11               0.0       940.0      RepBarragan
# 12               0.0       940.0     RepJoeBarton
# 13               0.0       940.0     RepKarenBass
# 14               0.0       940.0        RepBeatty
# 15               0.0       940.0          RepBera
# 16               0.0       940.0   RepJackBergman
# 17               0.0       940.0      repdonbeyer
# 18               0.0       940.0   RepAndyBiggsAZ
# 19               0.0       940.0  RepGusBilirakis
# 20               0.0       940.0    SanfordBishop
# 21               0.0       940.0    RepMikeBishop
# 22               0.0       940.0     RepRobBishop
# 23               0.0       940.0    RepDianeBlack
# 24               0.0       940.0  MarshaBlackburn
# 25               1.0       940.0       RepRodBlum
# 178480            https://wagner.house.gov                97.77       136083
# 178481           https://walberg.house.gov                94.03         8618
# 178482            https://walden.house.gov                94.75         2979
# 178483            https://walker.house.gov                96.28       146255
# 178484          https://walorski.house.gov                98.17        34205
# 178485           https://walters.house.gov                98.29        29346
# 178486              https://walz.house.gov                92.70        65443
# 178487  https://wassermanschultz.house.gov                93.59        24301
# 178488            https://waters.house.gov                93.36        26759
# 178489     https://watsoncoleman.house.gov                92.96        24799
# 178490             https://weber.house.gov                94.16       102026
# 178491           https://webster.house.gov                96.45        24302
# 178492             https://welch.house.gov                93.66        51272
# 178493          https://wenstrup.house.gov                96.48       135326
# 178494         https://westerman.house.gov                97.11       119120
# 178495          https://williams.house.gov                96.77        50112
# 178496            https://wilson.house.gov                95.04        17319
# 178497         https://joewilson.house.gov                98.07         3985
# 178498           https://wittman.house.gov                94.73        58133
# 178499            https://womack.house.gov                97.87        71815
# 178500           https://woodall.house.gov                93.09       122251
# 178501           https://yarmuth.house.gov                94.95        58579
# 178502             https://yoder.house.gov                93.44        34433
# 178503              https://yoho.house.gov                94.83       137622
# 178504        https://davidyoung.house.gov                96.49       155218
# 178505          https://donyoung.house.gov                90.04        26717
#
#             youtube_account                                        geo_a  \
# 0                      None  POINT (-91.82491765269089 31.7677401747569)
# 1            RobertAderholt  POINT (-91.82491765269089 31.7677401747569)
# 2                      None  POINT (-91.82491765269089 31.7677401747569)
# 3                      None  POINT (-91.82491765269089 31.7677401747569)
# 4             markamodeinv2  POINT (-91.82491765269089 31.7677401747569)
# 5                      None  POINT (-91.82491765269089 31.7677401747569)
# 6                      None  POINT (-91.82491765269089 31.7677401747569)
# 7                      None  POINT (-91.82491765269089 31.7677401747569)
# 8                      None  POINT (-91.82491765269089 31.7677401747569)
# 9            reploubarletta  POINT (-91.82491765269089 31.7677401747569)
# 10              RepAndyBarr                                          NaN
# 11                     None                                          NaN
# 12             repjoebarton                                          NaN
# 13             RepKarenBass                                          NaN
# 14                     None                                          NaN
# 15               repamibera                                          NaN
# 16                     None                                          NaN
# 17                     None                                          NaN
# 18                     None                                          NaN
# 19          RepGusBilirakis                                          NaN
# 20         RepSanfordBishop                                          NaN
# 21                     None                                          NaN
# 22        CongressmanBishop                                          NaN
# 23            RepDianeBlack                                          NaN
# 24       RepMarshaBlackburn                                          NaN
# 25                     None                                          NaN
# 26            RepBlumenauer                                          NaN
# 27                     None                                          NaN
# 28       RepSuzanneBonamici                                          NaN
# 29                     None                                          NaN
# ...                     ...                                          ...
# 178476           marcveasey                                          NaN
# 178477                 None                                          NaN
# 178478       nydiavelazquez                                          NaN
# 178479       PeteVisclosky1                                          NaN
# 178480                 None                                          NaN
# 178481           RepWalberg                                          NaN
# 178482        RepGregWalden                                          NaN
# 178483                 None                                          NaN
# 178484          repwalorski                                          NaN
# 178485                 None                                          NaN
# 178486              1529tjw                                          NaN
# 178487  RepWassermanSchultz                                          NaN
# 178488         MaxineWaters                                          NaN
# 178489                 None                                          NaN
# 178490            TXRandy14                                          NaN
# 178491        repdanwebster                                          NaN
# 178492        reppeterwelch                                          NaN
# 178493      repbradwenstrup                                          NaN
# 178494                 None                                          NaN
# 178495                 None                                          NaN
# 178496   repfredericawilson                                          NaN
# 178497         RepJoeWilson                                          NaN
# 178498           RobWittman                                          NaN
# 178499    CongressmanWomack                                          NaN
# 178500       RobWoodallGA07                                          NaN
# 178501       RepJohnYarmuth                                          NaN
# 178502             RepYoder                                          NaN
# 178503           RepTedYoho                                          NaN
# 178504                 None                                          NaN
# 178505          RepDonYoung                                          NaN
#
#                                                geo_b
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7       POINT (-96.15977113285999 41.22942767258883)
# 8                                                NaN
# 9                                                NaN
# 10                                               NaN
# 11                                               NaN
# 12                                               NaN
# 13                                               NaN
# 14                                               NaN
# 15                                               NaN
# 16                                               NaN
# 17                                               NaN
# 18                                               NaN
# 19                                               NaN
# 20                                               NaN
# 21                                               NaN
# 22                                               NaN
# 23                                               NaN
# 24                                               NaN
# 25                                               NaN
# 26                                               NaN
# 27                                               NaN
# 28                                               NaN
# 29                                               NaN
# ...                                              ...
# 178476                                           NaN
# 178477                                           NaN
# 178478                                           NaN
# 178479                                           NaN
# 178480                                           NaN
# 178481                                           NaN
# 178482                                           NaN
# 178483                                           NaN
# 178484                                           NaN
# 178485                                           NaN
# 178486                                           NaN
# 178487                                           NaN
# 178488                                           NaN
# 178489                                           NaN
# 178490                                           NaN
# 178491                                           NaN
# 178492                                           NaN
# 178493                                           NaN
# 178494                                           NaN
# 178495                                           NaN
# 178496                                           NaN
# 178497                                           NaN
# 178498                                           NaN
# 178499                                           NaN
# 178500                                           NaN
# 178501                                           NaN
# 178502                                           NaN
# 178503                                           NaN
# 178504                                           NaN
# 178505                                           NaN
#
# [178506 rows x 88 columns]

# %%
districts[districts.GEOID == '3202'].centroids.reset_index(drop=True)
# Out:
# 0    POINT (-117.3060329020225 40.64564001854976)
# Name: centroids, dtype: object

# %%
member_pairs.geoid.iloc[:5,1]
# Out:
# 0    3712
# 1    0104
# 2    0631
# 3    1312
# 4    3202
# Name: geoid, dtype: object

# %%
def insert_geoinfo(gid):
    #find geoinformation of A and of B in districts df, append to member_pairs df 
    geoinfo = districts[districts.GEOID == gid].centroids.reset_index(drop=True)
    return geoinfo

#df_list = [insert_geoinfo]

member_pairs['geo_a'] = member_pairs.geoid.iloc[:10,0].apply(insert_geoinfo) #reference member
member_pairs['geo_b'] = member_pairs.geoid.iloc[:5,1].apply(insert_geoinfo) #all other members

# %%
member_pairs.geo_b
# Out:
# 0         POINT (-80.8553640882194 35.27409102666888)
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#                              ...
# 178476                                            NaN
# 178477                                            NaN
# 178478                                            NaN
# 178479                                            NaN
# 178480                                            NaN
# 178481                                            NaN
# 178482                                            NaN
# 178483                                            NaN
# 178484                                            NaN
# 178485                                            NaN
# 178486                                            NaN
# 178487                                            NaN
# 178488                                            NaN
# 178489                                            NaN
# 178490                                            NaN
# 178491                                            NaN
# 178492                                            NaN
# 178493                                            NaN
# 178494                                            NaN
# 178495                                            NaN
# 178496                                            NaN
# 178497                                            NaN
# 178498                                            NaN
# 178499                                            NaN
# 178500                                            NaN
# 178501                                            NaN
# 178502                                            NaN
# 178503                                            NaN
# 178504                                            NaN
# 178505                                            NaN
# Name: geo_b, Length: 178506, dtype: object

# %%
#calculate distance between geo_a and geo_b (both centroids)
def get_dist(centr_a, centr_b):
    dist = centr_a.distance(member_pairs.geo_b)
    return dist
member_pairs['distance'] = member_pairs.geo_a.apply(get_dist)

# %%
centroids
